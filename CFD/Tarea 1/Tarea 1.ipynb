# %%
print("hola")
print("wena saco wea")

for i in range(10):
    print("saco wea rafa")
# Out:
# hola
# wena saco wea
# saco wea rafa
# saco wea rafa
# saco wea rafa
# saco wea rafa
# saco wea rafa
# saco wea rafa
# saco wea rafa
# saco wea rafa
# saco wea rafa
# saco wea rafa
